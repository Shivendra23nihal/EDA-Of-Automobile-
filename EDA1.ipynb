# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
car = pd.read_csv("austo_automobile.csv")    # data collection

# %%
car
# Out:
#       Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0      53    Male   Business        Married  Post Graduate                 4
# 1      53   Femal   Salaried        Married  Post Graduate                 4
# 2      53  Female   Salaried        Married  Post Graduate                 3
# 3      53  Female   Salaried        Married       Graduate                 2
# 4      53    Male   Salaried        Married  Post Graduate                 3
# ...   ...     ...        ...            ...            ...               ...
# 1576   22    Male   Salaried         Single       Graduate                 2
# 1577   22    Male   Business        Married       Graduate                 4
# 1578   22    Male   Business         Single       Graduate                 2
# 1579   22    Male   Business        Married       Graduate                 3
# 1580   22    Male   Salaried        Married       Graduate                 4
#
# ...

# %%
car.head()  # top 5 records
# Out:
#    Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   53    Male   Business        Married  Post Graduate                 4
# 1   53   Femal   Salaried        Married  Post Graduate                 4
# 2   53  Female   Salaried        Married  Post Graduate                 3
# 3   53  Female   Salaried        Married       Graduate                 2
# 4   53    Male   Salaried        Married  Post Graduate                 3
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No         No             Yes   99300         70700.0
# 1           Yes         No             Yes   95500         70300.0
# 2            No         No             Yes   97300         60700.0
# 3           Yes         No             Yes   72500         70300.0
# 4            No         No             Yes   79700         60200.0
#
#    Total_salary  Price Make
# 0        170000  61000  SUV
# 1        165800  61000  SUV
# 2        158000  57000  SUV
# ...

# %% [markdown]
# # Data Profiling

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1528 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1475 non-null   float64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 173.1+ KB

# %%
car.duplicated().sum()
# Out:
# np.int64(0)

# %%
car.Gender.unique()
# Out:
# array(['Male', 'Femal', 'Female', nan, 'Femle'], dtype=object)

# %%
car.Profession.unique()
# Out:
# array(['Business', 'Salaried'], dtype=object)

# %%
car.Marital_status.unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
car.Education.unique()
# Out:
# array(['Post Graduate', 'Graduate'], dtype=object)

# %%
car.No_of_Dependents.unique()
# Out:
# array([4, 3, 2, 1, 0])

# %%
car.Personal_loan.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
car.House_loan.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
car.Partner_working.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
car.Salary.unique()
# Out:
# array([99300, 95500, 97300, 72500, 79700, 79800, 80900, 79100, 89400,
#        83700, 81600, 81300, 77400, 77600, 74100, 87600, 86800, 95100,
#        92600, 98400, 72700, 84600, 88000, 85400, 78000, 87900, 81900,
#        88500, 87700, 98300, 94900, 91100, 74500, 81700, 84700, 82200,
#        79600, 77700, 72100, 96600, 72800, 73500, 90000, 87100, 90300,
#        72200, 78300, 90200, 79500, 73400, 90600, 93900, 80600, 85100,
#        82300, 79200, 70600, 79300, 72000, 88200, 81000, 78400, 75400,
#        91000, 89700, 78800, 89800, 89900, 88700, 88900, 83300, 79000,
#        77500, 76800, 71700, 89500, 77000, 86000, 86900, 85900, 79900,
#        74800, 98600, 76100, 82700, 92300, 87500, 80100, 78700, 78100,
#        78200, 77900, 86100, 86600, 77800, 76300, 76200, 87200, 81200,
#        73300, 98900, 97700, 72600, 74200, 90700, 84000, 84800, 80200,
#        70400, 71000, 84300, 53800, 85200, 85600, 80400, 77100, 76000,
# ...

# %%
car.isnull().sum()   # to find missing values
# Out:
# Age                   0
# Gender               53
# Profession            0
# Marital_status        0
# Education             0
# No_of_Dependents      0
# Personal_loan         0
# House_loan            0
# Partner_working       0
# Salary                0
# Partner_salary      106
# Total_salary          0
# Price                 0
# Make                  0
# dtype: int64

# %%
#null handalind

# %%
car.Gender.value_counts()
# Out:
# Gender
# Male      1199
# Female     327
# Femal        1
# Femle        1
# Name: count, dtype: int64

# %%
car.Gender=car.Gender.replace(["Femal","Femle"],["Female","Female"])
# correct the wrong words with correct words

# %%
car.Gender.value_counts()
# Out:
# Gender
# Male      1199
# Female     329
# Name: count, dtype: int64

# %%
car.Gender= car.Gender.fillna("Male")
# fill 53  null values with the male (Male is the most frequent category in this column)

# %%
car.isnull().sum()
#cheak null counts
# Out:
# Age                   0
# Gender                0
# Profession            0
# Marital_status        0
# Education             0
# No_of_Dependents      0
# Personal_loan         0
# House_loan            0
# Partner_working       0
# Salary                0
# Partner_salary      106
# Total_salary          0
# Price                 0
# Make                  0
# dtype: int64

# %%
car.Partner_salary=car.Total_salary-car.Salary

# %%
car.isnull().sum()
# Out:
# Age                 0
# Gender              0
# Profession          0
# Marital_status      0
# Education           0
# No_of_Dependents    0
# Personal_loan       0
# House_loan          0
# Partner_working     0
# Salary              0
# Partner_salary      0
# Total_salary        0
# Price               0
# Make                0
# dtype: int64

# %%
car.columns
# Out:
# Index(['Age', 'Gender', 'Profession', 'Marital_status', 'Education',
#        'No_of_Dependents', 'Personal_loan', 'House_loan', 'Partner_working',
#        'Salary', 'Partner_salary', 'Total_salary', 'Price', 'Make'],
#       dtype='object')

# %% [markdown]
# # Univariate Analysis

# %%
plt.hist(car.Age ,bins=5)       # histogram chart banega via matplotlib hist function se jese age ka bana hai.
plt.grid()
plt.show()

# %%
sns.countplot(x="Gender",data=car,hue="Gender")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x="Profession",data=car,hue="Profession")
# Out:
# <Axes: xlabel='Profession', ylabel='count'>

# %%
sns.countplot(x="Marital_status",data=car,hue="Marital_status")
# Out:
# <Axes: xlabel='Marital_status', ylabel='count'>

# %%
sns.countplot(x="Education",data=car,hue="Education")
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
plt.hist(car.No_of_Dependents , bins=5)
plt.grid()
plt.show()

# %%
sns.countplot(x="Personal_loan",data=car,hue="Personal_loan")
# Out:
# <Axes: xlabel='Personal_loan', ylabel='count'>

# %%
sns.countplot(x="House_loan",data=car,hue="House_loan")
# Out:
# <Axes: xlabel='House_loan', ylabel='count'>

# %%
sns.countplot(x="Partner_working",data=car,hue="Partner_working")
# Out:
# <Axes: xlabel='Partner_working', ylabel='count'>

# %%
plt.hist(car.Salary,bins=5)
plt.grid()
plt.show()

# %%
plt.hist(car.Partner_salary,bins=5)
plt.grid()
plt.show()

# %%
plt.hist(car.Total_salary,bins=5)
plt.grid()
plt.show()

# %%
plt.hist(car.Price,bins=5)
plt.grid()
plt.show()

# %%
sns.countplot(x="Make",data=car,hue="Make")
# Out:
# <Axes: xlabel='Make', ylabel='count'>

# %%
'''
1. Male> Female
2. salaried > Business
3. married > single 4. Pg > graduation:
5. Personal_loan : equal
6. house_loan : no > yes
7. partner_loan : yes>noc
8. sedan > hatchback > suv8-2
9. most of the custumer are in the range of 20-28
10. 59k-71k'''
# Out:
# '\n1. Male> Female\n2. salaried > Business\n3. married > single 4. Pg > graduation:\n5. Personal_loan : equal\n6. house_loan : no > yes\n7. partner_loan : yes>noc\n8. sedan > hatchback > suv8-2\n9. most of the custumer are in the range of 20-28\n10. 59k-71k'

# %% [markdown]
# # Bi-variente Analysis

# %%
car.columns
# Out:
# Index(['Age', 'Gender', 'Profession', 'Marital_status', 'Education',
#        'No_of_Dependents', 'Personal_loan', 'House_loan', 'Partner_working',
#        'Salary', 'Partner_salary', 'Total_salary', 'Price', 'Make'],
#       dtype='object')

# %%
'''1: Gender and Make 
2: Profession and Make 
3: Marital_status and Make 
4: Education and Make 
5: No_of_dependentas and Make 
6: Personal_loan and Make 
7: House_loan and Make
8: Partner_working and Make '''
# Out:
# '1: Gender and Make \n2: Profession and Make \n3: Marital_status and Make \n4: Education and Make \n5: No_of_dependentas and Make \n6: Personal_loan and Make \n7: House_loan and Make\n8: Partner_working and Make '

# %% [markdown]
# # 1: Gender and Make

# %%
car.groupby(["Gender","Marital_status","Make"])["Make"].count().unstack()   # unsatck se pivot tbale bnti hai
# Out:
# Make                   Hatchback  SUV  Sedan
# Gender Marital_status
# Female Married                14  166    127
#        Single                  1    7     14
# Male   Married               484  115    537
#        Single                 83    9     24

# %%
pd.crosstab(car.Gender,car.Make)
# Out:
# Make    Hatchback  SUV  Sedan
# Gender
# Female         15  173    141
# Male          567  124    561

# %%
car.Gender.value_counts()
# Out:
# Gender
# Male      1252
# Female     329
# Name: count, dtype: int64

# %%
sample1=car[car.Gender =="Male"][["Gender","Make"]].sample(329).groupby(["Make"]).count().rename(columns={"Gender":"Male"})

# %%
sample2=car[car.Gender =="Male"][["Gender","Make"]].sample(329).groupby(["Make"]).count().rename(columns={"Gender":"Male"})

# %%
sample3=car[car.Gender =="Male"][["Gender","Make"]].sample(329).groupby(["Make"]).count().rename(columns={"Gender":"Male"})

# %%
sample1
# Out:
#            Male
# Make
# Hatchback   153
# SUV          35
# Sedan       141

# %%
sample2
# Out:
#            Male
# Make
# Hatchback   155
# SUV          28
# Sedan       146

# %%
sample3
# Out:
#            Male
# Make
# Hatchback   158
# SUV          36
# Sedan       135

# %%
female=car[car.Gender =="Female"][["Gender","Make"]].groupby(["Make"]).count().rename(columns={"Gender":"Female"})

# %%
female
# Out:
#            Female
# Make
# Hatchback      15
# SUV           173
# Sedan         141

# %%
pd.concat([sample1,female],axis=1)
# Out:
#            Male  Female
# Make
# Hatchback   153      15
# SUV          35     173
# Sedan       141     141

# %%
pd.concat([sample1,female],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
pd.concat([sample2,female],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
pd.concat([sample3,female],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
# 1: Females are most intrested in SUV.
#2: Male are more Intrested in Hatchback.
#3: Both have almost similer intrested in SEDAN.

# %% [markdown]
# # 2: Profession and Make

# %%
car.groupby(["Profession","Make"])["Make"].count().unstack()
# Out:
# Make        Hatchback  SUV  Sedan
# Profession
# Business          290   89    306
# Salaried          292  208    396

# %%
car.Profession.value_counts()
# Out:
# Profession
# Salaried    896
# Business    685
# Name: count, dtype: int64

# %%
sample11=car[car.Profession =="Salaried"][["Profession","Make"]].sample(685).groupby(["Make"]).count().rename(columns={"Profession":"Salaried"})

# %%
sample11
# Out:
#            Salaried
# Make
# Hatchback       222
# SUV             164
# Sedan           299

# %%
sample12=car[car.Profession =="Salaried"][["Profession","Make"]].sample(685).groupby(["Make"]).count().rename(columns={"Profession":"Salaried"})

# %%
sample12
# Out:
#            Salaried
# Make
# Hatchback       224
# SUV             157
# Sedan           304

# %%
sample13=car[car.Profession =="Salaried"][["Profession","Make"]].sample(685).groupby(["Make"]).count().rename(columns={"Profession":"Salaried"})

# %%
sample13
# Out:
#            Salaried
# Make
# Hatchback       212
# SUV             154
# Sedan           319

# %%
business=car[car.Profession =="Business"][["Profession","Make"]].groupby(["Make"]).count().rename(columns={"Profession":"Business"})

# %%
business
# Out:
#            Business
# Make
# Hatchback       290
# SUV              89
# Sedan           306

# %%
pd.concat([sample11,business],axis=1)
# Out:
#            Salaried  Business
# Make
# Hatchback       222       290
# SUV             164        89
# Sedan           299       306

# %%
pd.concat([sample12,business],axis=1)
# Out:
#            Salaried  Business
# Make
# Hatchback       224       290
# SUV             157        89
# Sedan           304       306

# %%
pd.concat([sample13,business],axis=1)
# Out:
#            Salaried  Business
# Make
# Hatchback       212       290
# SUV             154        89
# Sedan           319       306

# %%
pd.concat([sample11,business],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
pd.concat([sample12,business],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
pd.concat([sample13,business],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
#1: Businesses are more intrested in Hatchback.
#2: Salaried are more intrested in SUV.
#3: Sedan is prefferd by both businesses and salaried.

# %% [markdown]
# # Marital_status and Make

# %%
car.groupby(["Marital_status","Make"])["Make"].count().unstack()
# Out:
# Make            Hatchback  SUV  Sedan
# Marital_status
# Married               498  281    664
# Single                 84   16     38

# %%
car.Marital_status.value_counts()
# Out:
# Marital_status
# Married    1443
# Single      138
# Name: count, dtype: int64

# %%
sample21=car[car.Marital_status=="Married"][["Marital_status","Make"]].sample(138).groupby(["Make"]).count().rename(columns={"Marital_status":"Married"})

# %%
sample22=car[car.Marital_status=="Married"][["Marital_status","Make"]].sample(138).groupby(["Make"]).count().rename(columns={"Marital_status":"Married"})

# %%
sample23=car[car.Marital_status=="Married"][["Marital_status","Make"]].sample(138).groupby(["Make"]).count().rename(columns={"Marital_status":"Married"})

# %%
sample21
# Out:
#            Married
# Make
# Hatchback       51
# SUV             23
# Sedan           64

# %%
sample22
# Out:
#            Married
# Make
# Hatchback       54
# SUV             23
# Sedan           61

# %%
sample23
# Out:
#            Married
# Make
# Hatchback       50
# SUV             22
# Sedan           66

# %%
single=car[car.Marital_status=="Single"][["Marital_status","Make"]].groupby(["Make"]).count().rename(columns={"Marital_status":"Single"})

# %%
single
# Out:
#            Single
# Make
# Hatchback      84
# SUV            16
# Sedan          38

# %%
pd.concat([sample21,single],axis=1)
# Out:
#            Married  Single
# Make
# Hatchback       51      84
# SUV             23      16
# Sedan           64      38

# %%
pd.concat([sample22,single],axis=1)
# Out:
#            Married  Single
# Make
# Hatchback       54      84
# SUV             23      16
# Sedan           61      38

# %%
pd.concat([sample23,single],axis=1)
# Out:
#            Married  Single
# Make
# Hatchback       50      84
# SUV             22      16
# Sedan           66      38

# %%
pd.concat([sample21,single],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
pd.concat([sample22,single],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
pd.concat([sample23,single],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
#1:Singles are more intrested in Hatchback as compare to Married
#2: Married are more intrested in SUV 
#3: Married are more intrested in Sedan.

# %% [markdown]
# # Education and Make

# %%
car.groupby(["Education","Make"])["Make"].count().unstack()
# Out:
# Make           Hatchback  SUV  Sedan
# Education
# Graduate             220  117    259
# Post Graduate        362  180    443

# %%
car.Education.value_counts()
# Out:
# Education
# Post Graduate    985
# Graduate         596
# Name: count, dtype: int64

# %%
sample31=car[car.Education=="Post Graduate"][["Education","Make"]].sample(596).groupby(["Make"]).count().rename(columns={"Education":"Post Graduate"})

# %%
sample32=car[car.Education=="Post Graduate"][["Education","Make"]].sample(596).groupby(["Make"]).count().rename(columns={"Education":"Post Graduate"})

# %%
sample33=car[car.Education=="Post Graduate"][["Education","Make"]].sample(596).groupby(["Make"]).count().rename(columns={"Education":"Post Graduate"})

# %%
sample31
# Out:
#            Post Graduate
# Make
# Hatchback            221
# SUV                  111
# Sedan                264

# %%
sample32
# Out:
#            Post Graduate
# Make
# Hatchback            212
# SUV                   98
# Sedan                286

# %%
sample33
# Out:
#            Post Graduate
# Make
# Hatchback            217
# SUV                  112
# Sedan                267

# %%
graduate=car[car.Education=="Graduate"][["Education","Make"]].groupby(["Make"]).count().rename(columns={"Education":"Graduate"})

# %%
graduate
# Out:
#            Graduate
# Make
# Hatchback       220
# SUV             117
# Sedan           259

# %%
pd.concat([sample31,graduate],axis=1)
# Out:
#            Post Graduate  Graduate
# Make
# Hatchback            221       220
# SUV                  111       117
# Sedan                264       259

# %%
pd.concat([sample31,graduate],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
pd.concat([sample32,graduate],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
pd.concat([sample33,graduate],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
#1: Hatchback are most intrested by both Graduate and Pg.
#2:  Graduate are most intrested in SUV
#3: Pg is more intrested in Sedan.

# %% [markdown]
# # No_of_Dependents and Make

# %%
car.groupby(["No_of_Dependents","Make"])["Make"].count().unstack()
# Out:
# Make              Hatchback    SUV  Sedan
# No_of_Dependents
# 0                      15.0    5.0    NaN
# 1                      11.0   34.0  184.0
# 2                     181.0   87.0  289.0
# 3                     256.0  117.0  184.0
# 4                     119.0   54.0   45.0

# %%
car.No_of_Dependents.value_counts()
# Out:
# No_of_Dependents
# 3    557
# 2    557
# 1    229
# 4    218
# 0     20
# Name: count, dtype: int64

# %%
sample41=car[car.No_of_Dependents==3][["No_of_Dependents","Make"]].sample(20).groupby(["Make"]).count().rename(columns={"No_of_Dependents":3})

# %%
sample42=car[car.No_of_Dependents==2][["No_of_Dependents","Make"]].sample(20).groupby(["Make"]).count().rename(columns={"No_of_Dependents":2})

# %%
sample43=car[car.No_of_Dependents==1][["No_of_Dependents","Make"]].sample(20).groupby(["Make"]).count().rename(columns={"No_of_Dependents":1})

# %%
sample44=car[car.No_of_Dependents==4][["No_of_Dependents","Make"]].sample(20).groupby(["Make"]).count().rename(columns={"No_of_Dependents":4})

# %%
sample41
# Out:
#             3
# Make
# Hatchback  11
# SUV         4
# Sedan       5

# %%
sample42
# Out:
#            2
# Make
# Hatchback  7
# SUV        5
# Sedan      8

# %%
sample43
# Out:
#             1
# Make
# Hatchback   2
# SUV         3
# Sedan      15

# %%
sample44
# Out:
#             4
# Make
# Hatchback  10
# SUV         6
# Sedan       4

# %%
zero=car[car.No_of_Dependents==0][["No_of_Dependents","Make"]].groupby(["Make"]).count().rename(columns={"No_of_Dependents":0})

# %%
zero
# Out:
#             0
# Make
# Hatchback  15
# SUV         5

# %%
pd.concat([sample41,zero],axis=1)
# Out:
#             3     0
# Make
# Hatchback  11  15.0
# SUV         4   5.0
# Sedan       5   NaN

# %%
pd.concat([sample42,zero],axis=1)
# Out:
#            2     0
# Make
# Hatchback  7  15.0
# SUV        5   5.0
# Sedan      8   NaN

# %%
pd.concat([sample43,zero],axis=1)
# Out:
#             1     0
# Make
# Hatchback   2  15.0
# SUV         3   5.0
# Sedan      15   NaN

# %%
pd.concat([sample44,zero],axis=1)
# Out:
#             4     0
# Make
# Hatchback  10  15.0
# SUV         6   5.0
# Sedan       4   NaN

# %%
pd.concat([sample41,zero],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
pd.concat([sample42,zero],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
pd.concat([sample43,zero],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
pd.concat([sample44,zero],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
#1: 0 No_of_Dependents is most intrested in Hatchback.
#2:  4 No_of_Dependents is most intrested in SUV.
#3: 3,2 & 1 No_of_Dependents is most intrested in Sedan

# %% [markdown]
# # Personal_loan and Make

# %%
car.groupby(["Personal_loan","Make"])["Make"].count().unstack()
# Out:
# Make           Hatchback  SUV  Sedan
# Personal_loan
# No                   291  181    317
# Yes                  291  116    385

# %%
car.Personal_loan.value_counts()
# Out:
# Personal_loan
# Yes    792
# No     789
# Name: count, dtype: int64

# %%
sample51=car[car.Personal_loan=="Yes"][["Personal_loan","Make"]].sample(789).groupby(["Make"]).count().rename(columns={"Personal_loan":"Yes"})

# %%
sample52=car[car.Personal_loan=="Yes"][["Personal_loan","Make"]].sample(789).groupby(["Make"]).count().rename(columns={"Personal_loan":"Yes"})

# %%
sample53=car[car.Personal_loan=="Yes"][["Personal_loan","Make"]].sample(789).groupby(["Make"]).count().rename(columns={"Personal_loan":"Yes"})

# %%
sample51
# Out:
#            Yes
# Make
# Hatchback  290
# SUV        115
# Sedan      384

# %%
sample52
# Out:
#            Yes
# Make
# Hatchback  290
# SUV        115
# Sedan      384

# %%
sample53
# Out:
#            Yes
# Make
# Hatchback  289
# SUV        116
# Sedan      384

# %%
no=car[car.Personal_loan=="No"][["Personal_loan","Make"]].groupby(["Make"]).count().rename(columns={"Personal_loan":"No"})

# %%
no
# Out:
#             No
# Make
# Hatchback  291
# SUV        181
# Sedan      317

# %%
pd.concat([sample51,no],axis=1)
# Out:
#            Yes   No
# Make
# Hatchback  290  291
# SUV        115  181
# Sedan      384  317

# %%
pd.concat([sample52,no],axis=1)
# Out:
#            Yes   No
# Make
# Hatchback  290  291
# SUV        115  181
# Sedan      384  317

# %%
pd.concat([sample53,no],axis=1)
# Out:
#            Yes   No
# Make
# Hatchback  289  291
# SUV        116  181
# Sedan      384  317

# %%
pd.concat([sample51,no],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
pd.concat([sample52,no],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
pd.concat([sample53,no],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
#1: Personal_loan almost same in Yes and No for Hatchback .
#2: Personal_loan  most prefferd to No for SUV.
#3: Personal_loan  most prefferd  to Yes for Sedan .

# %% [markdown]
# # House_loan and Make

# %%
car.groupby(["House_loan","Make"])["Make"].count().unstack()
# Out:
# Make        Hatchback  SUV  Sedan
# House_loan
# No                347  275    432
# Yes               235   22    270

# %%
car.House_loan.value_counts()
# Out:
# House_loan
# No     1054
# Yes     527
# Name: count, dtype: int64

# %%
sample61=car[car.House_loan=="No"][["House_loan","Make"]].sample(527).groupby(["Make"]).count().rename(columns={"House_loan":"No"})

# %%
sample62=car[car.House_loan=="No"][["House_loan","Make"]].sample(527).groupby(["Make"]).count().rename(columns={"House_loan":"No"})

# %%
sample63=car[car.House_loan=="No"][["House_loan","Make"]].sample(527).groupby(["Make"]).count().rename(columns={"House_loan":"No"})

# %%
sample61
# Out:
#             No
# Make
# Hatchback  171
# SUV        141
# Sedan      215

# %%
sample62
# Out:
#             No
# Make
# Hatchback  173
# SUV        140
# Sedan      214

# %%
sample63
# Out:
#             No
# Make
# Hatchback  186
# SUV        124
# Sedan      217

# %%
yes=car[car.House_loan=="Yes"][["House_loan","Make"]].groupby(["Make"]).count().rename(columns={"House_loan":"Yes"})

# %%
yes
# Out:
#            Yes
# Make
# Hatchback  235
# SUV         22
# Sedan      270

# %%
pd.concat([sample61,yes],axis=1)
# Out:
#             No  Yes
# Make
# Hatchback  171  235
# SUV        141   22
# Sedan      215  270

# %%
pd.concat([sample62,yes],axis=1)
# Out:
#             No  Yes
# Make
# Hatchback  173  235
# SUV        140   22
# Sedan      214  270

# %%
pd.concat([sample63,yes],axis=1)
# Out:
#             No  Yes
# Make
# Hatchback  186  235
# SUV        124   22
# Sedan      217  270

# %%
pd.concat([sample61,yes],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
pd.concat([sample62,yes],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
pd.concat([sample63,yes],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
#1: House_loan  most prefferd to Yes for Hatchback.
#2: House_loan most prefferd to No for Suv .
#3: House_loan  most prefferd  to Yes for Sedan .

# %%
car.columns
# Out:
# Index(['Age', 'Gender', 'Profession', 'Marital_status', 'Education',
#        'No_of_Dependents', 'Personal_loan', 'House_loan', 'Partner_working',
#        'Salary', 'Partner_salary', 'Total_salary', 'Price', 'Make'],
#       dtype='object')

# %% [markdown]
# # Partner_working and Make

# %%
car.groupby(["Partner_working","Make"])["Make"].count().unstack()
# Out:
# Make             Hatchback  SUV  Sedan
# Partner_working
# No                     281  144    288
# Yes                    301  153    414

# %%
car.Partner_working.value_counts()
# Out:
# Partner_working
# Yes    868
# No     713
# Name: count, dtype: int64

# %%
sample71=car[car.Partner_working=="Yes"][["Partner_working","Make"]].sample(713).groupby(["Make"]).count().rename(columns={"Partner_working":"Yes"})

# %%
sample72=car[car.Partner_working=="Yes"][["Partner_working","Make"]].sample(713).groupby(["Make"]).count().rename(columns={"Partner_working":"Yes"})

# %%
sample73=car[car.Partner_working=="Yes"][["Partner_working","Make"]].sample(713).groupby(["Make"]).count().rename(columns={"Partner_working":"Yes"})

# %%
sample71
# Out:
#            Yes
# Make
# Hatchback  243
# SUV        125
# Sedan      345

# %%
sample72
# Out:
#            Yes
# Make
# Hatchback  253
# SUV        126
# Sedan      334

# %%
sample73
# Out:
#            Yes
# Make
# Hatchback  247
# SUV        126
# Sedan      340

# %%
no=car[car.Partner_working=="No"][["Partner_working","Make"]].groupby(["Make"]).count().rename(columns={"Partner_working":"No"})

# %%
no
# Out:
#             No
# Make
# Hatchback  281
# SUV        144
# Sedan      288

# %%
pd.concat([sample71,no],axis=1)
# Out:
#            Yes   No
# Make
# Hatchback  243  281
# SUV        125  144
# Sedan      345  288

# %%
pd.concat([sample72,no],axis=1)
# Out:
#            Yes   No
# Make
# Hatchback  253  281
# SUV        126  144
# Sedan      334  288

# %%
pd.concat([sample73,no],axis=1)
# Out:
#            Yes   No
# Make
# Hatchback  247  281
# SUV        126  144
# Sedan      340  288

# %%
pd.concat([sample71,no],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
pd.concat([sample72,no],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
pd.concat([sample73,no],axis=1).plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
#1: Partner_working to most prefferd No for Hatchback .
#2: Partner_working to most prefferd No for Suv .
#3: Partner_working to most prefferd Yes for Sedan .

# %% [markdown]
# # Multi-variant

# %%
#1: Gender ,Marital_status and Make
#2: Gender ,Profession and Make.
#3: Gender, Personal_loan and Make
#4: Gender ,House_loan and Make

# %%
car.groupby(["Gender","Marital_status","Make"])["Make"].count().unstack().plot.bar()
# Out:
# <Axes: xlabel='Gender,Marital_status'>

# %%
#1: Female,Married most  intrested in SUV
#2: Fermale,Single most intrested in Sedan
#3: Male,Married most intrested in Sedan
#4: Male,Single most intrestyed in Hatchback

# %%
car.groupby(["Gender","Profession","Make"])["Make"].count().unstack().plot.bar()
# Out:
# <Axes: xlabel='Gender,Profession'>

# %%
#1: Female , Business most intrested in  SUV
#2: Female, Salried most intrested in SUV
#3: Male, Business most intrested in Hatchback.
#4: male, Salried most intrested in Sedan

# %%
car.groupby(["Gender","Personal_loan","Make"])["Make"].count().unstack().plot.bar()
# Out:
# <Axes: xlabel='Gender,Personal_loan'>

# %%
#1: Female , No in personal_loan for Suv.
#2: Female , Yes and No for personal_loan almost samne for SUV  & SEDAN.
#3: Male , No in personal loan for Hatchback.
#4: Male , Yes for Personal_loan for Sedan.

# %%
car.groupby(["Gender","House_loan","Make"])["Make"].count().unstack().plot.bar()
# Out:
# <Axes: xlabel='Gender,House_loan'>

# %%
#1: Female , No in House_loan for Suv.
#2: Female , Yes in House_loan for Sedan
#3: Male , No in House_loan for Sedan
#4: Male , Yes in House_loan for Hatchback

# %%
Report : Structer document of your Project:
1: what data you have
2: what you explored
3:
# Out:
#   Cell In[201], line 1
#     Report : Structer document of your Project:
#                       ^
# SyntaxError: invalid syntax
